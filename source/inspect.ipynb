# %%
import pandas as pd
import numpy as nb
import json

# %%
jack = None
with open('/Users/nguyentrunganhonichan/Documents/Discord_bot/source/requested_news.json', 'r') as p:
    jack = json.load(p)

# %%
# df = pd.DataFrame(jack)
# print(df.duplicated().sum())
# print(len(df))
